# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import time

import tensorflow as tf
import keras 
print("tf version: ", tf.__version__)
print("keras version: ", keras.__version__)
# Out:
# tf version:  2.0.0
# keras version:  2.3.1
# Using TensorFlow backend.

# %%
from keras import layers
from keras import models
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
from keras.callbacks import LearningRateScheduler

# %%
base_dir = os.getcwd()

# %%
base_dir
# Out:
# 'G:\\2021work\\SW-Project\\paper'

# %%
'''
train_dir = os.path.join(base_dir, 'train')
os.mkdir(train_dir)

test_dir = os.path.join(base_dir, 'test')
os.mkdir(test_dir)

train_morse_dir = os.path.join(train_dir, 'morse')
os.mkdir(train_morse_dir)

train_noise_dir = os.path.join(train_dir, 'noise')
os.mkdir(train_noise_dir)

test_morse_dir = os.path.join(test_dir, 'morse')
os.mkdir(test_morse_dir)

test_noise_dir = os.path.join(test_dir, 'noise')
os.mkdir(test_noise_dir)
'''
# Out:
# "\ntrain_dir = os.path.join(base_dir, 'train')\nos.mkdir(train_dir)\n\ntest_dir = os.path.join(base_dir, 'test')\nos.mkdir(test_dir)\n\ntrain_morse_dir = os.path.join(train_dir, 'morse')\nos.mkdir(train_morse_dir)\n\ntrain_noise_dir = os.path.join(train_dir, 'noise')\nos.mkdir(train_noise_dir)\n\ntest_morse_dir = os.path.join(test_dir, 'morse')\nos.mkdir(test_morse_dir)\n\ntest_noise_dir = os.path.join(test_dir, 'noise')\nos.mkdir(test_noise_dir)\n"

# %%
train_dir = os.path.join(base_dir, 'train')
test_dir = os.path.join(base_dir, 'test')
train_morse_dir = os.path.join(train_dir, 'morse')
train_noise_dir = os.path.join(train_dir, 'noise')
test_morse_dir = os.path.join(test_dir, 'morse')
test_noise_dir = os.path.join(test_dir, 'noise')
print('훈련용 이미지 전체 개수:', len(os.listdir(train_morse_dir)))
# Out:
# 훈련용 이미지 전체 개수: 173

# %%
fname = os.listdir(train_morse_dir)[0]
img_path = os.path.join(train_morse_dir, fname)
img = image.load_img(img_path, target_size=(300, 100))
img
# Out:
# <PIL.Image.Image image mode=RGB size=100x300 at 0x2310F31DB38>

# %%
# 모든 이미지를 1/255로 스케일 조정
train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        # 타깃 디렉터리
        train_dir,
        # 모든 이미지를 150 × 150 크기로 변경
        target_size=(300, 100),
        batch_size=30,
        # binary_crossentropy 손실을 사용하기 때문에 이진 레이블 필요
        # (다중분류시 class_mode='categorical'(원-핫 인코딩 레이블) 혹은 class_mode='sparse'(정수형 레이블))
        class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(300, 100),
        batch_size=20,
        class_mode='categorical')
# Out:
# Found 346 images belonging to 2 classes.
# Found 80 images belonging to 2 classes.

# %%
model = models.Sequential()
model.add(layers.Conv2D(8, (5, 3), activation='relu', padding ='same',
                        input_shape=(300, 100, 3)))
#model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(16, (5, 3), padding ='same', activation='relu'))
#model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(16, (5, 3), padding ='same', activation='relu'))
#model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(32, (5, 3), padding ='same', activation='relu'))
#model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.AveragePooling2D((1, 6)))
model.add(layers.Reshape((18,32)))

#model.add(layers.Bidirectional(layers.LSTM(32, return_sequences=True, dropout=0.1, recurrent_dropout=0.2)))
#model.add(layers.Bidirectional(layers.LSTM(32, dropout=0.1, recurrent_dropout=0.2)))

model.add(layers.LSTM(32, return_sequences=True, dropout=0.1, recurrent_dropout=0.2))
model.add(layers.LSTM(32, dropout=0.1, recurrent_dropout=0.2))

#model.add(layers.Flatten()) # 구분기의 입력으로 연결하기 위하여 3D 텐서를 1D 텐서로 펼침
#model.add(layers.Dropout(0.3))
#model.add(layers.Dense(64, activation='relu'))
#model.add(layers.Dense(2, activation='softmax'))

model.add(layers.Dense(64, activation='elu'))
#model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.2))
model.add(layers.Dense(2, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 300, 100, 8)       368
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 150, 50, 8)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 150, 50, 16)       1936
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 75, 25, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 75, 25, 16)        3856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 37, 12, 16)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 37, 12, 32)        7712
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 18, 6, 32)         0
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 18, 1, 32)         0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 18, 32)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 18, 32)            8320
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 32)                8320
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 32,754
# Trainable params: 32,754
# Non-trainable params: 0
# _________________________________________________________________

# %%
# learning rate 구간별로 설정 0.1 ~ 0.001
def lr_schedule(epoch):
    lr = 1e-3
    if epoch > 100: # # Second step-decay
        lr *= 1e-2
    elif epoch > 80: # First step-decay
        lr *= 1e-1
    print('Learning rate : ', lr)
    
    return lr 

# callback 설정 - step-decay learning rate schedule
callback_list = [LearningRateScheduler(lr_schedule)]

# %%
#optimizer=optimizers.RMSprop(lr=1e-3),
model.compile(loss='categorical_crossentropy',
              optimizer=optimizers.Adam(lr=1e-3),
              metrics=['acc'])

# %%
startTime = time.time()

# 제너레이터 사용시 fit_generator 메서드 사용
history = model.fit_generator(
      train_generator, #입력과 레이블의 배치를 끝없이 생성
      epochs=120,
      callbacks=callback_list,
      validation_data=validation_generator) #배치가 20개로 설정, 전체 검증 데이터 1,000개를 사용하려면, 50개의 배치 추출 필요
print("Computation time:{0:.3f} min.".format((time.time() - startTime)/60))
# Out:
# Epoch 1/120
# Learning rate :  0.001
# 12/12 [==============================] - 2s 208ms/step - loss: 0.6935 - acc: 0.5202 - val_loss: 0.7000 - val_acc: 0.5000
# Epoch 2/120
# Learning rate :  0.001
# 12/12 [==============================] - 1s 83ms/step - loss: 0.6964 - acc: 0.5116 - val_loss: 0.7003 - val_acc: 0.5625
# Epoch 3/120
# Learning rate :  0.001
# 12/12 [==============================] - 1s 103ms/step - loss: 0.6890 - acc: 0.5405 - val_loss: 0.6711 - val_acc: 0.5625
# Epoch 4/120
# Learning rate :  0.001
# 12/12 [==============================] - 1s 103ms/step - loss: 0.6848 - acc: 0.5231 - val_loss: 0.6979 - val_acc: 0.5500
# Epoch 5/120
# Learning rate :  0.001
# 12/12 [==============================] - 1s 104ms/step - loss: 0.6983 - acc: 0.5405 - val_loss: 0.6688 - val_acc: 0.5000
# Epoch 6/120
# Learning rate :  0.001
# 12/12 [==============================] - 1s 102ms/step - loss: 0.6778 - acc: 0.5578 - val_loss: 0.6742 - val_acc: 0.6000
# Epoch 7/120
# Learning rate :  0.001
# 12/12 [==============================] - 1s 107ms/step - loss: 0.6706 - acc: 0.5694 - val_loss: 0.7025 - val_acc: 0.6125
# Epoch 8/120
# Learning rate :  0.001
# 12/12 [==============================] - 1s 101ms/step - loss: 0.6576 - acc: 0.5867 - val_loss: 0.6651 - val_acc: 0.5125
# Epoch 9/120
# Learning rate :  0.001
# 12/12 [==============================] - 1s 104ms/step - loss: 0.6510 - acc: 0.6069 - val_loss: 0.5696 - val_acc: 0.6250
# Epoch 10/120
# Learning rate :  0.001
# 12/12 [==============================] - 1s 104ms/step - loss: 0.6043 - acc: 0.6590 - val_loss: 0.6715 - val_acc: 0.6000 0s - loss: 0.6203 - acc: 0
# Epoch 11/120
# Learning rate :  0.001
# 12/12 [==============================] - 1s 105ms/step - loss: 0.5713 - acc: 0.6936 - val_loss: 0.4319 - val_acc: 0.6375
# Epoch 12/120
# Learning rate :  0.001
# 12/12 [==============================] - 1s 104ms/step - loss: 0.5864 - acc: 0.6618 - val_loss: 0.4322 - val_acc: 0.7250
# Epoch 13/120
# Learning rate :  0.001
# 12/12 [==============================] - 1s 104ms/step - loss: 0
120
# Learning rate :  0.0001
# 12/12 [==============================] - 1s 96ms/step - loss: 0.0323 - acc: 0.9884 - val_loss: 0.5062 - val_acc: 0.8750
# Epoch 98/120
# Learning rate :  0.0001
# 12/12 [==============================] - 1s 105ms/step - loss: 0.0380 - acc: 0.9913 - val_loss: 0.2337 - val_acc: 0.9000
# Epoch 99/120
# Learning rate :  0.0001
# 12/12 [==============================] - 1s 104ms/step - loss: 0.0416 - acc: 0.9827 - val_loss: 0.1867 - val_acc: 0.9000
# Epoch 100/120
# Learning rate :  0.0001
# 12/12 [==============================] - 1s 106ms/step - loss: 0.0326 - acc: 0.9855 - val_loss: 0.2881 - val_acc: 0.8750
# Epoch 101/120
# Learning rate :  0.0001
# 12/12 [==============================] - 1s 100ms/step - loss: 0.0417 - acc: 0.9798 - val_loss: 0.1202 - val_acc: 0.8750
# Epoch 102/120
# Learning rate :  1e-05
# 12/12 [==============================] - 1s 102ms/step - loss: 0.0400 - acc: 0.9884 - val_loss: 0.1383 - val_acc: 0.8750
# Epoch 103/120
# Learning rate :  1e-05
# 12/12 [==============================] - 1s 96ms/step - loss: 0.0379 - acc: 0.9884 - val_loss: 0.4866 - val_acc: 0.9000
# Epoch 104/120
# Learning rate :  1e-05
# 12/12 [==============================] - 1s 103ms/step - loss: 0.0248 - acc: 0.9913 - val_loss: 0.3417 - val_acc: 0.8875
# Epoch 105/120
# Learning rate :  1e-05
# 12/12 [==============================] - 1s 103ms/step - loss: 0.0454 - acc: 0.9827 - val_loss: 0.3251 - val_acc: 0.9000
# Epoch 106/120
# Learning rate :  1e-05
# 12/12 [==============================] - 1s 97ms/step - loss: 0.0358 - acc: 0.9798 - val_loss: 0.2911 - val_acc: 0.8875
# Epoch 107/120
# Learning rate :  1e-05
# 12/12 [==============================] - 1s 104ms/step - loss: 0.0362 - acc: 0.9884 - val_loss: 0.3925 - val_acc: 0.8875
# Epoch 108/120
# Learning rate :  1e-05
# 12/12 [==============================] - 1s 101ms/step - loss: 0.0387 - acc: 0.9827 - val_loss: 0.2592 - val_acc: 0.9000
# Epoch 109/120
# Learning rate :  1e-05
# 12/12 [==============================] - 1s 97ms/step - loss: 0.0341 - acc: 0.9855 - val_loss: 0.2062 - val_acc: 0.9000
# Epoch 110/120
# Learning rate :  1e-05
# 12/12 [==============================] - 1s 103ms/step - loss: 0.0513 - acc: 0.9884 - val_loss: 0.4461 - val_acc: 0.9000
# Epoch 111/120
# Learning rate :  1e-05
# 12/12 [==============================] - 1s 102ms/step - loss: 0.0220 - acc: 0.9884 - val_loss: 0.4618 - val_acc: 0.9000
# Epoch 112/120
# Learning rate :  1e-05
# 12/12 [==============================] - 1s 117ms/step - loss: 0.0270 - acc: 0.9884 - val_loss: 0.1622 - val_acc: 0.9000
# Epoch 113/120
# Learning rate :  1e-05
# 12/12 [==============================] - 1s 101ms/step - loss: 0.0381 - acc: 0.9827 - val_loss: 0.1523 - val_acc: 0.9000
# Epoch 114/120
# Learning rate :  1e-05
# 12/12 [==============================] - 1s 105ms/step - loss: 0.0231 - acc: 0.9884 - val_loss: 0.1484 - val_acc: 0.9125
# Epoch 115/120
# Learning rate :  1e-05
# 12/12 [==============================] - 1s 106ms/step - loss: 0.0444 - acc: 0.9855 - val_loss: 0.3240 - val_acc: 0.9125
# Epoch 116/120
# Learning rate :  1e-05
# 12/12 [==============================] - 1s 98ms/step - loss: 0.0301 - acc: 0.9913 - val_loss: 0.2252 - val_acc: 0.9125
# Epoch 117/120
# Learning rate :  1e-05
# 12/12 [==============================] - 1s 105ms/step - loss: 0.0355 - acc: 0.9855 - val_loss: 0.1431 - val_acc: 0.9125
# Epoch 118/120
# Learning rate :  1e-05
# 12/12 [==============================] - 1s 106ms/step - loss: 0.0341 - acc: 0.9884 - val_loss: 0.3558 - val_acc: 0.9125
# Epoch 119/120
# Learning rate :  1e-05
# 12/12 [==============================] - 1s 102ms/step - loss: 0.0388 - acc: 0.9855 - val_loss: 0.2830 - val_acc: 0.9125: 0s - loss: 0.0446 - acc: 0.98
# Epoch 120/120
# Learning rate :  1e-05
# 12/12 [==============================] - 1s 107ms/step - loss: 0.0377 - acc: 0.9913 - val_loss: 0.3130 - val_acc: 0.9125
# Computation time:2.485 min.

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
##### Obtain test result in terms of classification accuracy
scores = model.evaluate_generator(validation_generator, steps=4)
scores
# Out:
# [0.31300628185272217, 0.9125000238418579]
